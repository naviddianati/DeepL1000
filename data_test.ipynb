# %% [markdown]
# # Generate training/holdout data using the packaged data generation script and inspect

# %%
import pandas as pd
import MOA_L1000.dataprep as dataprep
import numpy as np
import os
from cmapPy.pandasGEXpress import parse, write_gctx
from pandas.testing import assert_index_equal
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %%
filename = "/home/navid/data/DeepL1000/raw/siginfo.txt"
siginfo = pd.read_csv(filename, sep="\t")

filename = "/home/navid/data/DeepL1000/raw/CORE_AB_pert_info_with_moa.txt"
pertinfo = pd.read_csv(filename, sep="\t")

filename = "/home/navid/data/DeepL1000/raw/modzs_lm_n127751x978.gctx"
gct = parse.parse(filename)

sig, perts, annots = dataprep.find_perts_with_sigs_in_top_n_cell_lines(siginfo, pertinfo, selected_doses=dataprep.SELECTED_DOSES, n_top_cells=7)
X_train, X_holdout, targets_train, targets_holdout = dataprep.generate_training_and_holdout_data(annots, sig, gct)
# Out:
# cell_id
# A375    1542.0
# HA1E    1542.0
# HELA    1544.0
# YAPC    1547.0
# PC3     1549.0
# MCF7    1552.0
# HT29    1554.0
# dtype: float64
# Index(['A375', 'HA1E', 'HELA', 'YAPC', 'PC3', 'MCF7', 'HT29'], dtype='object', name='cell_id')
# cell_id
# HELA    1548.0
# PC3     1551.0
# HA1E    1552.0
# YAPC    1552.0
# A375    1553.0
# HT29    1554.0
# MCF7    1554.0
# dtype: float64
# Index(['HELA', 'PC3', 'HA1E', 'YAPC', 'A375', 'HT29', 'MCF7'], dtype='object', name='cell_id')
# cell_id
# HELA    1552.0
# A375    1557.0
# HA1E    1557.0
# PC3     1557.0
# HT29    1558.0
# MCF7    1558.0
# YAPC    1558.0
# dtype: float64
# Index(['HELA', 'A375', 'HA1E', 'PC3', 'HT29', 'MCF7', 'YAPC'], dtype='object', name='cell_id')
# Total number of perts found for the selected doses and cell lines: 1,555
# Total number of perts with available labels: 1,418
# /home/navid/Software/python3/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass shuffle=True, random_state=2 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# Selecting moas that have at least 4 compounds in train and 1 compounds in holdout
# Number of MOAs selected: 100
# Shape of targets_train: (3367, 100)
# Shape of targets_holdout: (846, 100)

# %%
assert targets_train.shape[0] == X_train.shape[0]
assert targets_holdout.shape[0] == X_holdout.shape[0]
assert_index_equal(targets_train.columns, targets_holdout.columns)

assert X_train.shape[1] == 978
assert X_holdout.shape[1] == 978

# %%
targets_train.sum(1).value_counts()
# Out:
# 1.0    2004
# 0.0    1061
# 2.0     229
# 3.0      52
# 5.0      12
# 4.0       9
# dtype: int64

# %%
print(X_train.shape)
print(X_holdout.shape)

print(targets_train.shape)
print(targets_holdout.shape)

targets_train.head()
# Out:
# (3367, 978, 7)
# (846, 978, 7)
# (3367, 100)
# (846, 100)
#                           PLK INHIBITOR  CCK RECEPTOR ANTAGONIST  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM               0.0                      0.0
#               10 uM                 0.0                      0.0
#               3.33 uM               0.0                      0.0
# BRD-A00218260 1.11 uM               0.0                      0.0
#               10 uM                 0.0                      0.0
#
#                           ANDROGEN RECEPTOR AGONIST  AROMATASE INHIBITOR  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                           0.0                  0.0
#               10 uM                             0.0                  0.0
#               3.33 uM                           0.0                  0.0
# BRD-A00218260 1.11 uM                           0.0                  0.0
#               10 uM                             0.0                  0.0
#
#                           IMMUNOSUPPRESSANT  PARP INHIBITOR  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                   0.0             0.0
#               10 uM                     0.0             0.0
#               3.33 uM                   0.0             0.0
# BRD-A00218260 1.11 uM                   0.0             0.0
#               10 uM                     0.0             0.0
#
#                           INTEGRIN INHIBITOR  MET INHIBITOR  CHELATING AGENT  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                    0.0            0.0              0.0
#               10 uM                      0.0            0.0              0.0
#               3.33 uM                    0.0            0.0              0.0
# BRD-A00218260 1.11 uM                    0.0            0.0              0.0
#               10 uM                      0.0            0.0              0.0
#
#                           THROMBOXANE RECEPTOR ANTAGONIST  ...  \
# pert_id       pert_idose                                   ...
# BRD-A00147595 1.11 uM                                 0.0  ...
#               10 uM                                   0.0  ...
#               3.33 uM                                 0.0  ...
# BRD-A00218260 1.11 uM                                 0.0  ...
#               10 uM                                   0.0  ...
#
#                           VEGFR INHIBITOR  ADRENERGIC RECEPTOR AGONIST  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                 0.0                          0.0
#               10 uM                   0.0                          0.0
#               3.33 uM                 0.0                          0.0
# BRD-A00218260 1.11 uM                 0.0                          0.0
#               10 uM                   0.0                          0.0
#
#                           CALCIUM CHANNEL BLOCKER  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                         0.0
#               10 uM                           0.0
#               3.33 uM                         0.0
# BRD-A00218260 1.11 uM                         0.0
#               10 uM                           0.0
#
#                           HISTAMINE RECEPTOR ANTAGONIST  DNA INHIBITOR  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                               0.0            0.0
#               10 uM                                 0.0            0.0
#               3.33 uM                               0.0            0.0
# BRD-A00218260 1.11 uM                               0.0            0.0
#               10 uM                                 0.0            0.0
#
#                           PHOSPHODIESTERASE INHIBITOR  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                             0.0
#               10 uM                               0.0
#               3.33 uM                             0.0
# BRD-A00218260 1.11 uM                             0.0
#               10 uM                               0.0
#
#                           DOPAMINE RECEPTOR ANTAGONIST  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                              0.0
#               10 uM                                0.0
#               3.33 uM                              0.0
# BRD-A00218260 1.11 uM                              0.0
#               10 uM                                0.0
#
#                           CYCLOOXYGENASE INHIBITOR  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                          0.0
#               10 uM                            0.0
#               3.33 uM                          0.0
# BRD-A00218260 1.11 uM                          0.0
#               10 uM                            0.0
#
#                           ADRENERGIC RECEPTOR ANTAGONIST  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                                0.0
#               10 uM                                  0.0
#               3.33 uM                                0.0
# BRD-A00218260 1.11 uM                                0.0
#               10 uM                                  0.0
#
#                           SEROTONIN RECEPTOR ANTAGONIST
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                               0.0
#               10 uM                                 0.0
#               3.33 uM                               0.0
# BRD-A00218260 1.11 uM                               0.0
#               10 uM                                 0.0
#
# [5 rows x 100 columns]

# %% [markdown]
# ## Run the packaged data generation script for version 1
# run make_data_v1()

# %%
dataprep.make_data_v1()
# Out:
# cell_id
# A375    1542.0
# HA1E    1542.0
# HELA    1544.0
# YAPC    1547.0
# PC3     1549.0
# MCF7    1552.0
# HT29    1554.0
# dtype: float64
# Index(['A375', 'HA1E', 'HELA', 'YAPC', 'PC3', 'MCF7', 'HT29'], dtype='object', name='cell_id')
# cell_id
# HELA    1548.0
# PC3     1551.0
# HA1E    1552.0
# YAPC    1552.0
# A375    1553.0
# HT29    1554.0
# MCF7    1554.0
# dtype: float64
# Index(['HELA', 'PC3', 'HA1E', 'YAPC', 'A375', 'HT29', 'MCF7'], dtype='object', name='cell_id')
# cell_id
# HELA    1552.0
# A375    1557.0
# HA1E    1557.0
# PC3     1557.0
# HT29    1558.0
# MCF7    1558.0
# YAPC    1558.0
# dtype: float64
# Index(['HELA', 'A375', 'HA1E', 'PC3', 'HT29', 'MCF7', 'YAPC'], dtype='object', name='cell_id')
# Total number of perts found for the selected doses and cell lines: 1,555
# Total number of perts with available labels: 1,418
# /home/navid/Software/python3/lib/python3.8/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass shuffle=True, random_state=2 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# Selecting moas that have at least 4 compounds in train and 1 compounds in holdout
# Number of MOAs selected: 100
# Shape of targets_train: (3367, 100)
# Shape of targets_holdout: (846, 100)

# %% [markdown]
# ## Load the generated training data

# %%
import MOA_L1000.dataprep as dataprep
import MOA_L1000.dataload as dataload

X_train, y_train, w_train, X_holdout, y_holdout = dataload.load_data_v1()
X_train.shape
# Out:
# (3367, 978, 7)

# %%
y_train.head(20)
# Out:
#                           PLK INHIBITOR  CCK RECEPTOR ANTAGONIST  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM               0.0                      0.0
#               10 uM                 0.0                      0.0
#               3.33 uM               0.0                      0.0
# BRD-A00218260 1.11 uM               0.0                      0.0
#               10 uM                 0.0                      0.0
#               3.33 uM               0.0                      0.0
# BRD-A00376169 1.11 uM               0.0                      0.0
#               10 uM                 0.0                      0.0
#               3.33 uM               0.0                      0.0
# BRD-A00546892 1.11 uM               0.0                      0.0
#               10 uM                 0.0                      0.0
#               3.33 uM               0.0                      0.0
# BRD-A01636364 1.11 uM               0.0                      0.0
#               10 uM                 0.0                      0.0
#               3.33 uM               0.0                      0.0
# BRD-A01787639 1.11 uM               0.0                      0.0
#               10 uM                 0.0                      0.0
#               3.33 uM               0.0                      0.0
# BRD-A02006392 1.11 uM               0.0                      0.0
#               10 uM                 0.0                      0.0
#
#                           ANDROGEN RECEPTOR AGONIST  AROMATASE INHIBITOR  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                           0.0                  0.0
#               10 uM                             0.0                  0.0
#               3.33 uM                           0.0                  0.0
# BRD-A00218260 1.11 uM                           0.0                  0.0
#               10 uM                             0.0                  0.0
#               3.33 uM                           0.0                  0.0
# BRD-A00376169 1.11 uM                           0.0                  0.0
#               10 uM                             0.0                  0.0
#               3.33 uM                           0.0                  0.0
# BRD-A00546892 1.11 uM                           0.0                  0.0
#               10 uM                             0.0                  0.0
#               3.33 uM                           0.0                  0.0
# BRD-A01636364 1.11 uM                           0.0                  0.0
#               10 uM                             0.0                  0.0
#               3.33 uM                           0.0                  0.0
# BRD-A01787639 1.11 uM                           0.0                  0.0
#               10 uM                             0.0                  0.0
#               3.33 uM                           0.0                  0.0
# BRD-A02006392 1.11 uM                           0.0                  0.0
#               10 uM                             0.0                  0.0
#
#                           IMMUNOSUPPRESSANT  PARP INHIBITOR  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                   0.0             0.0
#               10 uM                     0.0             0.0
#               3.33 uM                   0.0             0.0
# BRD-A00218260 1.11 uM                   0.0             0.0
#               10 uM                     0.0             0.0
#               3.33 uM                   0.0             0.0
# BRD-A00376169 1.11 uM                   0.0             0.0
#               10 uM                     0.0             0.0
#               3.33 uM                   0.0             0.0
# BRD-A00546892 1.11 uM                   0.0             0.0
#               10 uM                     0.0             0.0
#               3.33 uM                   0.0             0.0
# BRD-A01636364 1.11 uM                   0.0             0.0
#               10 uM                     0.0             0.0
#               3.33 uM                   0.0             0.0
# BRD-A01787639 1.11 uM                   0.0             0.0
#               10 uM                     0.0             0.0
#               3.33 uM                   0.0             0.0
# BRD-A02006392 1.11 uM                   0.0             0.0
#               10 uM                     0.0             0.0
#
#                           INTEGRIN INHIBITOR  MET INHIBITOR  CHELATING AGENT  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                    0.0            0.0              0.0
#               10 uM                      0.0            0.0              0.0
#               3.33 uM                    0.0            0.0              0.0
# BRD-A00218260 1.11 uM                    0.0            0.0              0.0
#               10 uM                      0.0            0.0              0.0
#               3.33 uM                    0.0            0.0              0.0
# BRD-A00376169 1.11 uM                    0.0            0.0              0.0
#               10 uM                      0.0            0.0              0.0
#               3.33 uM                    0.0            0.0              0.0
# BRD-A00546892 1.11 uM                    0.0            0.0              0.0
#               10 uM                      0.0            0.0              0.0
#               3.33 uM                    0.0            0.0              0.0
# BRD-A01636364 1.11 uM                    0.0            0.0              0.0
#               10 uM                      0.0            0.0              0.0
#               3.33 uM                    0.0            0.0              0.0
# BRD-A01787639 1.11 uM                    0.0            0.0              0.0
#               10 uM                      0.0            0.0              0.0
#               3.33 uM                    0.0            0.0              0.0
# BRD-A02006392 1.11 uM                    0.0            0.0              0.0
#               10 uM                      0.0            0.0              0.0
#
#                           THROMBOXANE RECEPTOR ANTAGONIST  ...  \
# pert_id       pert_idose                                   ...
# BRD-A00147595 1.11 uM                                 0.0  ...
#               10 uM                                   0.0  ...
#               3.33 uM                                 0.0  ...
# BRD-A00218260 1.11 uM                                 0.0  ...
#               10 uM                                   0.0  ...
#               3.33 uM                                 0.0  ...
# BRD-A00376169 1.11 uM                                 0.0  ...
#               10 uM                                   0.0  ...
#               3.33 uM                                 0.0  ...
# BRD-A00546892 1.11 uM                                 0.0  ...
#               10 uM                                   0.0  ...
#               3.33 uM                                 0.0  ...
# BRD-A01636364 1.11 uM                                 0.0  ...
#               10 uM                                   0.0  ...
#               3.33 uM                                 0.0  ...
# BRD-A01787639 1.11 uM                                 0.0  ...
#               10 uM                                   0.0  ...
#               3.33 uM                                 0.0  ...
# BRD-A02006392 1.11 uM                                 0.0  ...
#               10 uM                                   0.0  ...
#
#                           VEGFR INHIBITOR  ADRENERGIC RECEPTOR AGONIST  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                 0.0                          0.0
#               10 uM                   0.0                          0.0
#               3.33 uM                 0.0                          0.0
# BRD-A00218260 1.11 uM                 0.0                          0.0
#               10 uM                   0.0                          0.0
#               3.33 uM                 0.0                          0.0
# BRD-A00376169 1.11 uM                 0.0                          0.0
#               10 uM                   0.0                          0.0
#               3.33 uM                 0.0                          0.0
# BRD-A00546892 1.11 uM                 0.0                          0.0
#               10 uM                   0.0                          0.0
#               3.33 uM                 0.0                          0.0
# BRD-A01636364 1.11 uM                 0.0                          0.0
#               10 uM                   0.0                          0.0
#               3.33 uM                 0.0                          0.0
# BRD-A01787639 1.11 uM                 0.0                          0.0
#               10 uM                   0.0                          0.0
#               3.33 uM                 0.0                          0.0
# BRD-A02006392 1.11 uM                 0.0                          0.0
#               10 uM                   0.0                          0.0
#
#                           CALCIUM CHANNEL BLOCKER  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                         0.0
#               10 uM                           0.0
#               3.33 uM                         0.0
# BRD-A00218260 1.11 uM                         0.0
#               10 uM                           0.0
#               3.33 uM                         0.0
# BRD-A00376169 1.11 uM                         0.0
#               10 uM                           0.0
#               3.33 uM                         0.0
# BRD-A00546892 1.11 uM                         0.0
#               10 uM                           0.0
#               3.33 uM                         0.0
# BRD-A01636364 1.11 uM                         0.0
#               10 uM                           0.0
#               3.33 uM                         0.0
# BRD-A01787639 1.11 uM                         0.0
#               10 uM                           0.0
#               3.33 uM                         0.0
# BRD-A02006392 1.11 uM                         1.0
#               10 uM                           1.0
#
#                           HISTAMINE RECEPTOR ANTAGONIST  DNA INHIBITOR  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                               0.0            0.0
#               10 uM                                 0.0            0.0
#               3.33 uM                               0.0            0.0
# BRD-A00218260 1.11 uM                               0.0            0.0
#               10 uM                                 0.0            0.0
#               3.33 uM                               0.0            0.0
# BRD-A00376169 1.11 uM                               0.0            0.0
#               10 uM                                 0.0            0.0
#               3.33 uM                               0.0            0.0
# BRD-A00546892 1.11 uM                               0.0            0.0
#               10 uM                                 0.0            0.0
#               3.33 uM                               0.0            0.0
# BRD-A01636364 1.11 uM                               0.0            0.0
#               10 uM                                 0.0            0.0
#               3.33 uM                               0.0            0.0
# BRD-A01787639 1.11 uM                               0.0            0.0
#               10 uM                                 0.0            0.0
#               3.33 uM                               0.0            0.0
# BRD-A02006392 1.11 uM                               0.0            0.0
#               10 uM                                 0.0            0.0
#
#                           PHOSPHODIESTERASE INHIBITOR  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                             0.0
#               10 uM                               0.0
#               3.33 uM                             0.0
# BRD-A00218260 1.11 uM                             0.0
#               10 uM                               0.0
#               3.33 uM                             0.0
# BRD-A00376169 1.11 uM                             0.0
#               10 uM                               0.0
#               3.33 uM                             0.0
# BRD-A00546892 1.11 uM                             0.0
#               10 uM                               0.0
#               3.33 uM                             0.0
# BRD-A01636364 1.11 uM                             0.0
#               10 uM                               0.0
#               3.33 uM                             0.0
# BRD-A01787639 1.11 uM                             0.0
#               10 uM                               0.0
#               3.33 uM                             0.0
# BRD-A02006392 1.11 uM                             0.0
#               10 uM                               0.0
#
#                           DOPAMINE RECEPTOR ANTAGONIST  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                              0.0
#               10 uM                                0.0
#               3.33 uM                              0.0
# BRD-A00218260 1.11 uM                              0.0
#               10 uM                                0.0
#               3.33 uM                              0.0
# BRD-A00376169 1.11 uM                              0.0
#               10 uM                                0.0
#               3.33 uM                              0.0
# BRD-A00546892 1.11 uM                              0.0
#               10 uM                                0.0
#               3.33 uM                              0.0
# BRD-A01636364 1.11 uM                              0.0
#               10 uM                                0.0
#               3.33 uM                              0.0
# BRD-A01787639 1.11 uM                              0.0
#               10 uM                                0.0
#               3.33 uM                              0.0
# BRD-A02006392 1.11 uM                              0.0
#               10 uM                                0.0
#
#                           CYCLOOXYGENASE INHIBITOR  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                          0.0
#               10 uM                            0.0
#               3.33 uM                          0.0
# BRD-A00218260 1.11 uM                          0.0
#               10 uM                            0.0
#               3.33 uM                          0.0
# BRD-A00376169 1.11 uM                          0.0
#               10 uM                            0.0
#               3.33 uM                          0.0
# BRD-A00546892 1.11 uM                          0.0
#               10 uM                            0.0
#               3.33 uM                          0.0
# BRD-A01636364 1.11 uM                          0.0
#               10 uM                            0.0
#               3.33 uM                          0.0
# BRD-A01787639 1.11 uM                          0.0
#               10 uM                            0.0
#               3.33 uM                          0.0
# BRD-A02006392 1.11 uM                          0.0
#               10 uM                            0.0
#
#                           ADRENERGIC RECEPTOR ANTAGONIST  \
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                                0.0
#               10 uM                                  0.0
#               3.33 uM                                0.0
# BRD-A00218260 1.11 uM                                0.0
#               10 uM                                  0.0
#               3.33 uM                                0.0
# BRD-A00376169 1.11 uM                                0.0
#               10 uM                                  0.0
#               3.33 uM                                0.0
# BRD-A00546892 1.11 uM                                0.0
#               10 uM                                  0.0
#               3.33 uM                                0.0
# BRD-A01636364 1.11 uM                                0.0
#               10 uM                                  0.0
#               3.33 uM                                0.0
# BRD-A01787639 1.11 uM                                1.0
#               10 uM                                  1.0
#               3.33 uM                                1.0
# BRD-A02006392 1.11 uM                                0.0
#               10 uM                                  0.0
#
#                           SEROTONIN RECEPTOR ANTAGONIST
# pert_id       pert_idose
# BRD-A00147595 1.11 uM                               0.0
#               10 uM                                 0.0
#               3.33 uM                               0.0
# BRD-A00218260 1.11 uM                               0.0
#               10 uM                                 0.0
#               3.33 uM                               0.0
# BRD-A00376169 1.11 uM                               0.0
#               10 uM                                 0.0
#               3.33 uM                               0.0
# BRD-A00546892 1.11 uM                               0.0
#               10 uM                                 0.0
#               3.33 uM                               0.0
# BRD-A01636364 1.11 uM                               0.0
#               10 uM                                 0.0
#               3.33 uM                               0.0
# BRD-A01787639 1.11 uM                               0.0
#               10 uM                                 0.0
#               3.33 uM                               0.0
# BRD-A02006392 1.11 uM                               0.0
#               10 uM                                 0.0
#
# [20 rows x 100 columns]

# %% [markdown]
# ## Design Transformer that for each sample (in each cell line) removes the median across all features

# %%
class TransformerRemoveMed:
    '''
    Remove gene and cell medians from each sample
    RobustScale all features
    '''
    
    def __init__(self):
        pass
    
    def fit(self, X):
        pass
        
    def transform(self, X):
        q25 = np.quantile(X, 0.25, axis=1)
        q75 = np.quantile(X, 0.75, axis=1)
        med = (q25  + q75) / 2

        # Give med a dummy dimension so its shape
        # matches that of X_train and we can subtract
        med = np.expand_dims(med, 1)

        X_transformed = np.subtract(X, med)
        return X_transformed

    def fit_transform(self, X):
        self.fit(X)
        return self.transform(X)

# %% [markdown]
# # Transformer that quantile transforms across all samples for each cell line

# %%
from sklearn.preprocessing import QuantileTransformer
class TransformerQuantileTransform:
    '''
    Quantile Transform across all features
    '''
    
    def __init__(self):
        self.quantile_transformers = [
            QuantileTransformer(n_quantiles=100, output_distribution="normal") for i in range(7)
        ]

    def fit(self, X):
        for i in range(7):
            self.quantile_transformers[i].fit(X[:, :, i])
    
    def transform(self, X):
        X_transformed = np.stack(
            [self.quantile_transformers[i].transform(X[:, :, i]) for i in range(7)],
            axis=2
        )
        return X_transformed

    def fit_transform(self, X):
        self.fit(X)
        return self.transform(X)

# %%
tr = TransformerQuantileTransform()
XX = tr.fit_transform(X_train)
